# %%
# 导入必要的库
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
from torchvision import transforms, datasets, models, utils
from torchsummary import summary # 可视化训练过程
from torch.utils.data import DataLoader
import time
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from PIL import Image

# %%
# 分为为train, val, test定义transform
image_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=300, scale=(0.8, 1.1)), #功能：随机长宽比裁剪原始图片, 表示随机crop出来的图片会在的0.08倍至1.1倍之间
        transforms.RandomRotation(degrees=10), #功能：根据degrees随机旋转一定角度, 则表示在（-10，+10）度之间随机旋转
        transforms.ColorJitter(0.4, 0.4, 0.4), #功能：修改亮度、对比度和饱和度
        transforms.RandomHorizontalFlip(), #功能：水平翻转
        transforms.CenterCrop(size=256), #功能：根据给定的size从中心裁剪，size - 若为sequence,则为(h,w)，若为int，则(size,size)
        transforms.ToTensor(), #numpy --> tensor
        # 功能：对数据按通道进行标准化（RGB），即先减均值，再除以标准差
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'val' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'test' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ])
}

# %%
# 加载数据集

# 数据集所在目录路径
data_dir = 'covidNormal/'
# train路径
train_dir = data_dir + 'train/'
# val路径
val_dir = data_dir + 'val/'
# test路径
test_dir = data_dir + 'test/'

# 从文件中读取数据
datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=image_transforms['train']), # 读取train中的数据集，并transform
    'val' : datasets.ImageFolder(val_dir, transform=image_transforms['val']),  # 读取val中的数据集，并transform
    'test' : datasets.ImageFolder(test_dir, transform=image_transforms['test']) #  读取test中的数据集，并transform
}

# 定义BATCH_SIZE
BATCH_SIZE = 128 # 每批读取128张图片

# DataLoader : 创建iterator, 按批读取数据
dataloaders = {
    'train' : DataLoader(datasets['train'], batch_size=BATCH_SIZE, shuffle=True), # 训练集
    'val' : DataLoader(datasets['val'], batch_size=BATCH_SIZE, shuffle=True), # 验证集
    'test' : DataLoader(datasets['test'], batch_size=BATCH_SIZE, shuffle=True) # 测试集
}

# 创建label的键值对
LABEL = dict((v, k) for k, v in datasets['train'].class_to_idx.items())

LABEL
# Out:
# {0: 'Covid19', 1: 'Normal'}

# %%
# train 简介
dataloaders['train'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 5000
#     Root location: covidNormal/train/
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(300, 300), scale=(0.8, 1.1), ratio=(0.75, 1.3333), interpolation=bilinear)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=None)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders['train'].dataset.classes # train下的类别
# Out:
# ['Covid19', 'Normal']

# %%
dataloaders['train'].dataset.root # train的路径
# Out:
# 'covidNormal/train/'

# %%
# 肺部细菌感染的图片
files_normal_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'Normal'))
files_normal_pneumonia
# Out:
# ['Normal (1).jpeg',
#  'Normal (1).png',
#  'Normal (10).jpeg',
#  'Normal (10).png',
#  'Normal (100).jpeg',
#  'Normal (100).png',
#  'Normal (1000).jpeg',
#  'Normal (1000).png',
#  'Normal (1001).jpeg',
#  'Normal (1001).png',
#  'Normal (1002).jpeg',
#  'Normal (1002).png',
#  'Normal (1003).jpeg',
#  'Normal (1003).png',
#  'Normal (1004).jpeg',
#  'Normal (1004).png',
#  'Normal (1005).jpeg',
#  'Normal (1005).png',
#  'Normal (1006).jpeg',
#  'Normal (1006).png',
#  'Normal (1007).jpeg',
#  'Normal (1007).png',
#  'Normal (1008).jpeg',
#  'Normal (1008).png',
#  'Normal (1009).jpeg',
#  'Normal (1009).png',
#  'Normal (101).jpeg',
#  'Normal (101).png',
#  'Normal (1010).jpeg',
#  'Normal (1010).png',
#  'Normal (1011).jpeg',
#  'Normal (1011).png',
#  'Normal (1012).jpeg',
#  'Normal (1012).png',
#  'Normal (1013).jpeg',
#  'Normal (1013).png',
#  'Normal (1014).jpeg',
#  'Normal (1014).png',
#  'Normal (1015).jpeg',
#  'Normal (1015).png',
#  'Normal (1016).jpeg',
#  'Normal (1016).png',
#  'Normal (1017).jpeg',
#  'Normal (1017).png',
#  'Normal (1018).jpeg',
#  'Normal (1018).png',
#  'Normal (1019).jpeg',
#  'Normal (1019).png',
#  'Normal (102).jpeg',
#  'Normal (102).png',
#  'Normal (1020).jpeg',
#  'Normal (1020).png',
#  'Normal (1021).jpeg',
#  'Normal (1021).png',
#  'Normal (1022).jpeg',
#  'Normal (1022).png',
#  'Normal (1023).jpeg',
#  'Normal (1023).png',
#  'Normal (1024).jpeg',
#  'Normal (1024).png',
#  'Normal (1025).jpeg',
#  'Normal (1025).png',
#  'Normal (1026).jpeg',
#  'Normal (1026).png',
#  'Normal (1027).jpeg',
#  'Normal (1027).png',
#  'Normal (1028).jpeg',
#  'Normal (1028).png',
#  'Normal (1029).jpeg',
#  'Normal (1029).png',
#  'Normal (103).jpeg',
#  'Normal (103).png',
#  'Normal (1030).jpeg',
#  'Normal (1030).png',
#  'Normal (1031).jpeg',
#  'Normal (1031).png',
#  'Normal (1032).jpeg',
#  'Normal (1032).png',
#  'Normal (1033).jpeg',
#  'Normal (1033).png',
#  'Normal (1034).jpeg',
#  'Normal (1034).png',
#  'Normal (1035).jpeg',
#  'Normal (1035).png',
#  'Normal (1036).jpeg',
#  'Normal (1036).png',
#  'Normal (1037).jpeg',
#  'Normal (1037).png',
#  'Normal (1038).jpeg',
#  'Normal (1038).png',
#  'Normal (1039).jpeg',
#  'Normal (1039).png',
#  'Normal (104).jpeg',
#  'Normal (104).png',
#  'Normal (1040).jpeg',
#  'Normal (1040).png',
#  'Normal (1041).jpeg',
#  'Normal (1041).png',
#  'Normal (1042).jpeg',
#  'Normal (1042).png',
#  'Normal (1043).jpeg',
#  'Normal (1043).png',
#  'Normal (1044).jpeg',
#  'Normal (1044).png',
#  'Normal (1045).jpeg',
#  'Normal (1045).png',
#  'Normal (1046).jpeg',
#  'Normal (1046).png',
#  'Normal (1047).jpeg',
#  'Normal (1047).png',
#  'Normal (1048).jpeg',
#  'Normal (1048).png',
#  'Normal (1049).jpeg',
#  'Normal (1049).png',
#  'Normal (105).jpeg',
#  'Normal (105).png',
#  'Normal (1050).jpeg',
#  'Normal (1050).png',
#  'Normal (1051).jpeg',
#  'Normal (1051).png',
#  'Normal (1052).jpeg',
#  'Normal (1052).png',
#  'Normal (1053).jpeg',
#  'Normal (1053).png',
#  'Normal (1054).jpeg',
#  'Normal (1054).png',
#  'Normal (1055).jpeg',
#  'Normal (1055).png',
#  'Normal (1056).jpeg',
#  'Normal (1056).png',
#  'Normal (1057).jpeg',
#  'Normal (1057).png',
#  'Normal (1058).jpeg',
#  'Normal (1058).png',
#  'Normal (1059).jpeg',
#  'Normal (1059).png',
#  'Normal (106).jpeg',
#  'Normal (106).png',
#  'Normal (1060).jpeg',
#  'Normal (1060).png',
#  'Normal (1061).jpeg',
#  'Normal (1061).png',
#  'Normal (1062).jpeg',
#  'Normal (1062).png',
#  'Normal (1063).jpeg',
#  'Normal (1063).png',
#  'Normal (1064).jpeg',
#  'Normal (1064).png',
#  'Normal (1065).jpeg',
#  'Normal (1065).png',
#  'Normal (1066).jpeg',
#  'Normal (1066).png',
#  'Normal (1067).jpeg',
#  'Normal (1067).png',
#  'Normal (1068).jpeg',
#  'Normal (1068).png',
#  'Normal (1069).jpeg',
#  'Normal (1069).png',
#  'Normal (107).jpeg',
#  'Normal (107).png',
#  'Normal (1070).jpeg',
#  'Normal (1070).png',
#  'Normal (1071).jpeg',
#  'Normal (1071).png',
#  'Normal (1072).jpeg',
#  'Normal (1072).png',
#  'Normal (1073).jpeg',
#  'Normal (1073).png',
#  'Normal (1074).jpeg',
#  'Normal (1074).png',
#  'Normal (1075).jpeg',
#  'Normal (1075).png',
#  'Normal (1076).jpeg',
#  'Normal (1076).png',
#  'Normal (1077).jpeg',
#  'Normal (1077).png',
#  'Normal (1078).jpeg',
#  'Normal (1078).png',
#  'Normal (1079).jpeg',
#  'Normal (1079).png',
#  'Normal (108).jpeg',
#  'Normal (108).png',
#  'Normal (1080).jpeg',
#  'Normal (1080).png',
#  'Normal (1081).jpeg',
#  'Normal (1081).png',
#  'Normal (1082).jpeg',
#  'Normal (1082).png',
#  'Normal (1083).jpeg',
#  'Normal (1083).png',
#  'Normal (1084).jpeg',
#  'Normal (1084).png',
#  'Normal (1085).jpeg',
#  'Normal (1085).png',
#  'Normal (1086).jpeg',
#  'Normal (1086).png',
#  'Normal (1087).jpeg',
#  'Normal (1087).png',
#  'Normal (1088).jpeg',
#  'Normal (1088).png',
#  'Normal (1089).jpeg',
#  'Normal (1089).png',
#  'Normal (109).jpeg',
#  'Normal (109).png',
#  'Normal (1090).jpeg',
#  'Normal (1090).png',
#  'Normal (1091).jpeg',
#  'Normal (1091).png',
#  'Normal (1092).jpeg',
#  'Normal (1092).png',
#  'Normal (1093).jpeg',
#  'Normal (1093).png',
#  'Normal (1094).jpeg',
#  'Normal (1094).png',
#  'Normal (1095).jpeg',
#  'Normal (1095).png',
#  'Normal (1096).jpeg',
#  'Normal (1096).png',
#  'Normal (1097).jpeg',
#  'Normal (1097).png',
#  'Normal (1098).jpeg',
#  'Normal (1098).png',
#  'Normal (1099).jpeg',
#  'Normal (1099).png',
#  'Normal (11).jpeg',
#  'Normal (11).png',
#  'Normal (110).jpeg',
#  'Normal (110).png',
#  'Normal (1100).jpeg',
#  'Normal (1100).png',
#  'Normal (1101).jpeg',
#  'Normal (1101).png',
#  'Normal (1102).jpeg',
#  'Normal (1102).png',
#  'Normal (1103).jpeg',
#  'Normal (1103).png',
#  'Normal (1104).jpeg',
#  'Normal (1104).png',
#  'Normal (1105).jpeg',
#  'Normal (1105).png',
#  'Normal (1106).jpeg',
#  'Normal (1106).png',
#  'Normal (1107).jpeg',
#  'Normal (1107).png',
#  'Normal (1108).jpeg',
#  'Normal (1108).png',
#  'Normal (1109).jpeg',
#  'Normal (1109).png',
#  'Normal (111).jpeg',
#  'Normal (111).png',
#  'Normal (1110).jpeg',
#  'Normal (1110).png',
#  'Normal (1111).jpeg',
#  'Normal (1111).png',
#  'Normal (1112).jpeg',
#  'Normal (1112).png',
#  'Normal (1113).jpeg',
#  'Normal (1113).png',
#  'Normal (1114).jpeg',
#  'Normal (1114).png',
#  'Normal (1115).jpeg',
#  'Normal (1115).png',
#  'Normal (1116).jpeg',
#  'Normal (1116).png',
#  'Normal (1117).jpeg',
#  'Normal (1117).png',
#  'Normal (1118).jpeg',
#  'Normal (1118).png',
#  'Normal (1119).jpeg',
#  'Normal (1119).png',
#  'Normal (112).jpeg',
#  'Normal (112).png',
#  'Normal (1120).jpeg',
#  'Normal (1120).png',
#  'Normal (1121).jpeg',
#  'Normal (1121).png',
#  'Normal (1122).jpeg',
#  'Normal (1122).png',
#  'Normal (1123).jpeg',
#  'Normal (1123).png',
#  'Normal (1124).jpeg',
#  'Normal (1124).png',
#  'Normal (1125).jpeg',
#  'Normal (1125).png',
#  'Normal (1126).jpeg',
#  'Normal (1126).png',
#  'Normal (1127).jpeg',
#  'Normal (1127).png',
#  'Normal (1128).jpeg',
#  'Normal (1128).png',
#  'Normal (1129).jpeg',
#  'Normal (1129).png',
#  'Normal (113).jpeg',
#  'Normal (113).png',
#  'Normal (1130).jpeg',
#  'Normal (1130).png',
#  'Normal (1131).jpeg',
#  'Normal (1131).png',
#  'Normal (1132).jpeg',
#  'Normal (1132).png',
#  'Normal (1133).jpeg',
#  'Normal (1133).png',
#  'Normal (1134).jpeg',
#  'Normal (1134).png',
#  'Normal (1135).jpeg',
#  'Normal (1135).png',
#  'Normal (1136).jpeg',
#  'Normal (1136).png',
#  'Normal (1137).jpeg',
#  'Normal (1137).png',
#  'Normal (1138).jpeg',
#  'Normal (1138).png',
#  'Normal (1139).jpeg',
#  'Normal (1139).png',
#  'Normal (114).jpeg',
#  'Normal (114).png',
#  'Normal (1140).jpeg',
#  'Normal (1140).png',
#  'Normal (1141).jpeg',
#  'Normal (1141).png',
#  'Normal (1142).jpeg',
#  'Normal (1142).png',
#  'Normal (1143).jpeg',
#  'Normal (1143).png',
#  'Normal (1144).jpeg',
#  'Normal (1144).png',
#  'Normal (1145).jpeg',
#  'Normal (1145).png',
#  'Normal (1146).jpeg',
#  'Normal (1146).png',
#  'Normal (1147).jpeg',
#  'Normal (1147).png',
#  'Normal (1148).jpeg',
#  'Normal (1148).png',
#  'Normal (1149).jpeg',
#  'Normal (1149).png',
#  'Normal (115).jpeg',
#  'Normal (115).png',
#  'Normal (1150).jpeg',
#  'Normal (1150).png',
#  'Normal (1151).jpeg',
#  'Normal (1151).png',
#  'Normal (1152).jpeg',
#  'Normal (1152).png',
#  'Normal (1153).jpeg',
#  'Normal (1153).png',
#  'Normal (1154).jpeg',
#  'Normal (1154).png',
#  'Normal (1155).jpeg',
#  'Normal (1155).png',
#  'Normal (1156).jpeg',
#  'Normal (1156).png',
#  'Normal (1157).jpeg',
#  'Normal (1157).png',
#  'Normal (1158).jpeg',
#  'Normal (1158).png',
#  'Normal (1159).jpeg',
#  'Normal (1159).png',
#  'Normal (116).jpeg',
#  'Normal (116).png',
#  'Normal (1160).jpeg',
#  'Normal (1160).png',
#  'Normal (1161).jpeg',
#  'Normal (1161).png',
#  'Normal (1162).jpeg',
#  'Normal (1162).png',
#  'Normal (1163).jpeg',
#  'Normal (1163).png',
#  'Normal (1164).jpeg',
#  'Normal (1164).png',
#  'Normal (1165).jpeg',
#  'Normal (1165).png',
#  'Normal (1166).jpeg',
#  'Normal (1166).png',
#  'Normal (1167).jpeg',
#  'Normal (1167).png',
#  'Normal (1168).jpeg',
#  'Normal (1168).png',
#  'Normal (1169).jpeg',
#  'Normal (1169).png',
#  'Normal (117).jpeg',
#  'Normal (117).png',
#  'Normal (1170).jpeg',
#  'Normal (1170).png',
#  'Normal (1171).jpeg',
#  'Normal (1171).png',
#  'Normal (1172).jpeg',
#  'Normal (1172).png',
#  'Normal (1173).jpeg',
#  'Normal (1173).png',
#  'Normal (1174).jpeg',
#  'Normal (1174).png',
#  'Normal (1175).jpeg',
#  'Normal (1175).png',
#  'Normal (1176).jpeg',
#  'Normal (1176).png',
#  'Normal (1177).jpeg',
#  'Normal (1177).png',
#  'Normal (1178).jpeg',
#  'Normal (1178).png',
#  'Normal (1179).jpeg',
#  'Normal (1179).png',
#  'Normal (118).jpeg',
#  'Normal (118).png',
#  'Normal (1180).jpeg',
#  'Normal (1180).png',
#  'Normal (1181).jpeg',
#  'Normal (1181).png',
#  'Normal (1182).jpeg',
#  'Normal (1182).png',
#  'Normal (1183).jpeg',
#  'Normal (1183).png',
#  'Normal (1184).jpeg',
#  'Normal (1184).png',
#  'Normal (1185).jpeg',
#  'Normal (1185).png',
#  'Normal (1186).jpeg',
#  'Normal (1186).png',
#  'Normal (1187).jpeg',
#  'Normal (1187).png',
#  'Normal (1188).jpeg',
#  'Normal (1188).png',
#  'Normal (1189).jpeg',
#  'Normal (1189).png',
#  'Normal (119).jpeg',
#  'Normal (119).png',
#  'Normal (1190).jpeg',
#  'Normal (1190).png',
#  'Normal (1191).jpeg',
#  'Normal (1191).png',
#  'Normal (1192).jpeg',
#  'Normal (1192).png',
#  'Normal (1193).jpeg',
#  'Normal (1193).png',
#  'Normal (1194).jpeg',
#  'Normal (1194).png',
#  'Normal (1195).jpeg',
#  'Normal (1195).png',
#  'Normal (1196).jpeg',
#  'Normal (1196).png',
#  'Normal (1197).jpeg',
#  'Normal (1197).png',
#  'Normal (1198).jpeg',
#  'Normal (1198).png',
#  'Normal (1199).jpeg',
#  'Normal (1199).png',
#  'Normal (12).jpeg',
#  'Normal (12).png',
#  'Normal (120).jpeg',
#  'Normal (120).png',
#  'Normal (1200).jpeg',
#  'Normal (1200).png',
#  'Normal (1201).jpeg',
#  'Normal (1201).png',
#  'Normal (1202).jpeg',
#  'Normal (1202).png',
#  'Normal (1203).jpeg',
#  'Normal (1203).png',
#  'Normal (1204).jpeg',
#  'Normal (1204).png',
#  'Normal (1205).jpeg',
#  'Normal (1205).png',
#  'Normal (1206).jpeg',
#  'Normal (1206).png',
#  'Normal (1207).jpeg',
#  'Normal (1207).png',
#  'Normal (1208).jpeg',
#  'Normal (1208).png',
#  'Normal (1209).jpeg',
#  'Normal (1209).png',
#  'Normal (121).jpeg',
#  'Normal (121).png',
#  'Normal (1210).jpeg',
#  'Normal (1210).png',
#  'Normal (1211).jpeg',
#  'Normal (1211).png',
#  'Normal (1212).jpeg',
#  'Normal (1212).png',
#  'Normal (1213).jpeg',
#  'Normal (1213).png',
#  'Normal (1214).jpeg',
#  'Normal (1214).png',
#  'Normal (1215).jpeg',
#  'Normal (1215).png',
#  'Normal (1216).jpeg',
#  'Normal (1216).png',
#  'Normal (1217).jpeg',
#  'Normal (1217).png',
#  'Normal (1218).jpeg',
#  'Normal (1218).png',
#  'Normal (1219).jpeg',
#  'Normal (1219).png',
#  'Normal (122).jpeg',
#  'Normal (122).png',
#  'Normal (1220).jpeg',
#  'Normal (1220).png',
#  'Normal (1221).jpeg',
#  'Normal (1221).png',
#  'Normal (1222).jpeg',
#  'Normal (1222).png',
#  'Normal (1223).jpeg',
#  'Normal (1223).png',
#  'Normal (1224).jpeg',
#  'Normal (1224).png',
#  'Normal (1225).jpeg',
#  'Normal (1225).png',
#  'Normal (1226).jpeg',
#  'Normal (1226).png',
#  'Normal (1227).jpeg',
#  'Normal (1227).png',
#  'Normal (1228).jpeg',
#  'Normal (1228).png',
#  'Normal (1229).jpeg',
#  'Normal (1229).png',
#  'Normal (123).jpeg',
#  'Normal (123).png',
#  'Normal (1230).jpeg',
#  'Normal (1230).png',
#  'Normal (1231).jpeg',
#  'Normal (1231).png',
#  'Normal (1232).jpeg',
#  'Normal (1232).png',
#  'Normal (1233).jpeg',
#  'Normal (1233).png',
#  'Normal (1234).jpeg',
#  'Normal (1234).png',
#  'Normal (1235).jpeg',
#  'Normal (1235).png',
#  'Normal (1236).jpeg',
#  'Normal (1236).png',
#  'Normal (1237).jpeg',
#  'Normal (1237).png',
#  'Normal (1238).jpeg',
#  'Normal (1238).png',
#  'Normal (1239).jpeg',
#  'Normal (1239).png',
#  'Normal (124).jpeg',
#  'Normal (124).png',
#  'Normal (1240).jpeg',
#  'Normal (1240).png',
#  'Normal (1241).jpeg',
#  'Normal (1241).png',
#  'Normal (1242).jpeg',
#  'Normal (1242).png',
#  'Normal (1243).jpeg',
#  'Normal (1243).png',
#  'Normal (1244).jpeg',
#  'Normal (1244).png',
#  'Normal (1245).jpeg',
#  'Normal (1245).png',
#  'Normal (1246).jpeg',
#  'Normal (1246).png',
#  'Normal (1247).jpeg',
#  'Normal (1247).png',
#  'Normal (1248).jpeg',
#  'Normal (1248).png',
#  'Normal (1249).jpeg',
#  'Normal (1249).png',
#  'Normal (125).jpeg',
#  'Normal (125).png',
#  'Normal (1250).jpeg',
#  'Normal (1250).png',
#  'Normal (126).jpeg',
#  'Normal (126).png',
#  'Normal (127).jpeg',
#  'Normal (127).png',
#  'Normal (128).jpeg',
#  'Normal (128).png',
#  'Normal (129).jpeg',
#  'Normal (129).png',
#  'Normal (13).jpeg',
#  'Normal (13).png',
#  'Normal (130).jpeg',
#  'Normal (130).png',
#  'Normal (131).jpeg',
#  'Normal (131).png',
#  'Normal (132).jpeg',
#  'Normal (132).png',
#  'Normal (133).jpeg',
#  'Normal (133).png',
#  'Normal (134).jpeg',
#  'Normal (134).png',
#  'Normal (135).jpeg',
#  'Normal (135).png',
#  'Normal (136).jpeg',
#  'Normal (136).png',
#  'Normal (137).jpeg',
#  'Normal (137).png',
#  'Normal (138).jpeg',
#  'Normal (138).png',
#  'Normal (139).jpeg',
#  'Normal (139).png',
#  'Normal (14).jpeg',
#  'Normal (14).png',
#  'Normal (140).jpeg',
#  'Normal (140).png',
#  'Normal (141).jpeg',
#  'Normal (141).png',
#  'Normal (142).jpeg',
#  'Normal (142).png',
#  'Normal (143).jpeg',
#  'Normal (143).png',
#  'Normal (144).jpeg',
#  'Normal (144).png',
#  'Normal (145).jpeg',
#  'Normal (145).png',
#  'Normal (146).jpeg',
#  'Normal (146).png',
#  'Normal (147).jpeg',
#  'Normal (147).png',
#  'Normal (148).jpeg',
#  'Normal (148).png',
#  'Normal (149).jpeg',
#  'Normal (149).png',
#  'Normal (15).jpeg',
#  'Normal (15).png',
#  'Normal (150).jpeg',
#  'Normal (150).png',
#  'Normal (151).jpeg',
#  'Normal (151).png',
#  'Normal (152).jpeg',
#  'Normal (152).png',
#  'Normal (153).jpeg',
#  'Normal (153).png',
#  'Normal (154).jpeg',
#  'Normal (154).png',
#  'Normal (155).jpeg',
#  'Normal (155).png',
#  'Normal (156).jpeg',
#  'Normal (156).png',
#  'Normal (157).jpeg',
#  'Normal (157).png',
#  'Normal (158).jpeg',
#  'Normal (158).png',
#  'Normal (159).jpeg',
#  'Normal (159).png',
#  'Normal (16).jpeg',
#  'Normal (16).png',
#  'Normal (160).jpeg',
#  'Normal (160).png',
#  'Normal (161).jpeg',
#  'Normal (161).png',
#  'Normal (162).jpeg',
#  'Normal (162).png',
#  'Normal (163).jpeg',
#  'Normal (163).png',
#  'Normal (164).jpeg',
#  'Normal (164).png',
#  'Normal (165).jpeg',
#  'Normal (165).png',
#  'Normal (166).jpeg',
#  'Normal (166).png',
#  'Normal (167).jpeg',
#  'Normal (167).png',
#  'Normal (168).jpeg',
#  'Normal (168).png',
#  'Normal (169).jpeg',
#  'Normal (169).png',
#  'Normal (17).jpeg',
#  'Normal (17).png',
#  'Normal (170).jpeg',
#  'Normal (170).png',
#  'Normal (171).jpeg',
#  'Normal (171).png',
#  'Normal (172).jpeg',
#  'Normal (172).png',
#  'Normal (173).jpeg',
#  'Normal (173).png',
#  'Normal (174).jpeg',
#  'Normal (174).png',
#  'Normal (175).jpeg',
#  'Normal (175).png',
#  'Normal (176).jpeg',
#  'Normal (176).png',
#  'Normal (177).jpeg',
#  'Normal (177).png',
#  'Normal (178).jpeg',
#  'Normal (178).png',
#  'Normal (179).jpeg',
#  'Normal (179).png',
#  'Normal (18).jpeg',
#  'Normal (18).png',
#  'Normal (180).jpeg',
#  'Normal (180).png',
#  'Normal (181).jpeg',
#  'Normal (181).png',
#  'Normal (182).jpeg',
#  'Normal (182).png',
#  'Normal (183).jpeg',
#  'Normal (183).png',
#  'Normal (184).jpeg',
#  'Normal (184).png',
#  'Normal (185).jpeg',
#  'Normal (185).png',
#  'Normal (186).jpeg',
#  'Normal (186).png',
#  'Normal (187).jpeg',
#  'Normal (187).png',
#  'Normal (188).jpeg',
#  'Normal (188).png',
#  'Normal (189).jpeg',
#  'Normal (189).png',
#  'Normal (19).jpeg',
#  'Normal (19).png',
#  'Normal (190).jpeg',
#  'Normal (190).png',
#  'Normal (191).jpeg',
#  'Normal (191).png',
#  'Normal (192).jpeg',
#  'Normal (192).png',
#  'Normal (193).jpeg',
#  'Normal (193).png',
#  'Normal (194).jpeg',
#  'Normal (194).png',
#  'Normal (195).jpeg',
#  'Normal (195).png',
#  'Normal (196).jpeg',
#  'Normal (196).png',
#  'Normal (197).jpeg',
#  'Normal (197).png',
#  'Normal (198).jpeg',
#  'Normal (198).png',
#  'Normal (199).jpeg',
#  'Normal (199).png',
#  'Normal (2).jpeg',
#  'Normal (2).png',
#  'Normal (20).jpeg',
#  'Normal (20).png',
#  'Normal (200).jpeg',
#  'Normal (200).png',
#  'Normal (201).jpeg',
#  'Normal (201).png',
#  'Normal (202).jpeg',
#  'Normal (202).png',
#  'Normal (203).jpeg',
#  'Normal (203).png',
#  'Normal (204).jpeg',
#  'Normal (204).png',
#  'Normal (205).jpeg',
#  'Normal (205).png',
#  'Normal (206).jpeg',
#  'Normal (206).png',
#  'Normal (207).jpeg',
#  'Normal (207).png',
#  'Normal (208).jpeg',
#  'Normal (208).png',
#  'Normal (209).jpeg',
#  'Normal (209).png',
#  'Normal (21).jpeg',
#  'Normal (21).png',
#  'Normal (210).jpeg',
#  'Normal (210).png',
#  'Normal (211).jpeg',
#  'Normal (211).png',
#  'Normal (212).jpeg',
#  'Normal (212).png',
#  'Normal (213).jpeg',
#  'Normal (213).png',
#  'Normal (214).jpeg',
#  'Normal (214).png',
#  'Normal (215).jpeg',
#  'Normal (215).png',
#  'Normal (216).jpeg',
#  'Normal (216).png',
#  'Normal (217).jpeg',
#  'Normal (217).png',
#  'Normal (218).jpeg',
#  'Normal (218).png',
#  'Normal (219).jpeg',
#  'Normal (219).png',
#  'Normal (22).jpeg',
#  'Normal (22).png',
#  'Normal (220).jpeg',
#  'Normal (220).png',
#  'Normal (221).jpeg',
#  'Normal (221).png',
#  'Normal (222).jpeg',
#  'Normal (222).png',
#  'Normal (223).jpeg',
#  'Normal (223).png',
#  'Normal (224).jpeg',
#  'Normal (224).png',
#  'Normal (225).jpeg',
#  'Normal (225).png',
#  'Normal (226).jpeg',
#  'Normal (226).png',
#  'Normal (227).jpeg',
#  'Normal (227).png',
#  'Normal (228).jpeg',
#  'Normal (228).png',
#  'Normal (229).jpeg',
#  'Normal (229).png',
#  'Normal (23).jpeg',
#  'Normal (23).png',
#  'Normal (230).jpeg',
#  'Normal (230).png',
#  'Normal (231).jpeg',
#  'Normal (231).png',
#  'Normal (232).jpeg',
#  'Normal (232).png',
#  'Normal (233).jpeg',
#  'Normal (233).png',
#  'Normal (234).jpeg',
#  'Normal (234).png',
#  'Normal (235).jpeg',
#  'Normal (235).png',
#  'Normal (236).jpeg',
#  'Normal (236).png',
#  'Normal (237).jpeg',
#  'Normal (237).png',
#  'Normal (238).jpeg',
#  'Normal (238).png',
#  'Normal (239).jpeg',
#  'Normal (239).png',
#  'Normal (24).jpeg',
#  'Normal (24).png',
#  'Normal (240).jpeg',
#  'Normal (240).png',
#  'Normal (241).jpeg',
#  'Normal (241).png',
#  'Normal (242).jpeg',
#  'Normal (242).png',
#  'Normal (243).jpeg',
#  'Normal (243).png',
#  'Normal (244).jpeg',
#  'Normal (244).png',
#  'Normal (245).jpeg',
#  'Normal (245).png',
#  'Normal (246).jpeg',
#  'Normal (246).png',
#  'Normal (247).jpeg',
#  'Normal (247).png',
#  'Normal (248).jpeg',
#  'Normal (248).png',
#  'Normal (249).jpeg',
#  'Normal (249).png',
#  'Normal (25).jpeg',
#  'Normal (25).png',
#  'Normal (250).jpeg',
#  'Normal (250).png',
#  'Normal (251).jpeg',
#  'Normal (251).png',
#  'Normal (252).jpeg',
#  'Normal (252).png',
#  'Normal (253).jpeg',
#  'Normal (253).png',
#  'Normal (254).jpeg',
#  'Normal (254).png',
#  'Normal (255).jpeg',
#  'Normal (255).png',
#  'Normal (256).jpeg',
#  'Normal (256).png',
#  'Normal (257).jpeg',
#  'Normal (257).png',
#  'Normal (258).jpeg',
#  'Normal (258).png',
#  'Normal (259).jpeg',
#  'Normal (259).png',
#  'Normal (26).jpeg',
#  'Normal (26).png',
#  'Normal (260).jpeg',
#  'Normal (260).png',
#  'Normal (261).jpeg',
#  'Normal (261).png',
#  'Normal (262).jpeg',
#  'Normal (262).png',
#  'Normal (263).jpeg',
#  'Normal (263).png',
#  'Normal (264).jpeg',
#  'Normal (264).png',
#  'Normal (265).jpeg',
#  'Normal (265).png',
#  'Normal (266).jpeg',
#  'Normal (266).png',
#  'Normal (267).jpeg',
#  'Normal (267).png',
#  'Normal (268).jpeg',
#  'Normal (268).png',
#  'Normal (269).jpeg',
#  'Normal (269).png',
#  'Normal (27).jpeg',
#  'Normal (27).png',
#  'Normal (270).jpeg',
#  'Normal (270).png',
#  'Normal (271).jpeg',
#  'Normal (271).png',
#  'Normal (272).jpeg',
#  'Normal (272).png',
#  'Normal (273).jpeg',
#  'Normal (273).png',
#  'Normal (274).jpeg',
#  'Normal (274).png',
#  'Normal (275).jpeg',
#  'Normal (275).png',
#  'Normal (276).jpeg',
#  'Normal (276).png',
#  'Normal (277).jpeg',
#  'Normal (277).png',
#  'Normal (278).jpeg',
#  'Normal (278).png',
#  'Normal (279).jpeg',
#  'Normal (279).png',
#  'Normal (28).jpeg',
#  'Normal (28).png',
#  'Normal (280).jpeg',
#  'Normal (280).png',
#  'Normal (281).jpeg',
#  'Normal (281).png',
#  'Normal (282).jpeg',
#  'Normal (282).png',
#  'Normal (283).jpeg',
#  'Normal (283).png',
#  'Normal (284).jpeg',
#  'Normal (284).png',
#  'Normal (285).jpeg',
#  'Normal (285).png',
#  'Normal (286).jpeg',
#  'Normal (286).png',
#  'Normal (287).jpeg',
#  'Normal (287).png',
#  'Normal (288).jpeg',
#  'Normal (288).png',
#  'Normal (289).jpeg',
#  'Normal (289).png',
#  'Normal (29).jpeg',
#  'Normal (29).png',
#  'Normal (290).jpeg',
#  'Normal (290).png',
#  'Normal (291).jpeg',
#  'Normal (291).png',
#  'Normal (292).jpeg',
#  'Normal (292).png',
#  'Normal (293).jpeg',
#  'Normal (293).png',
#  'Normal (294).jpeg',
#  'Normal (294).png',
#  'Normal (295).jpeg',
#  'Normal (295).png',
#  'Normal (296).jpeg',
#  'Normal (296).png',
#  'Normal (297).jpeg',
#  'Normal (297).png',
#  'Normal (298).jpeg',
#  'Normal (298).png',
#  'Normal (299).jpeg',
#  'Normal (299).png',
#  'Normal (3).jpeg',
#  'Normal (3).png',
#  'Normal (30).jpeg',
#  'Normal (30).png',
#  'Normal (300).jpeg',
#  'Normal (300).png',
#  'Normal (301).jpeg',
#  'Normal (301).png',
#  'Normal (302).jpeg',
#  'Normal (302).png',
#  'Normal (303).jpeg',
#  'Normal (303).png',
#  'Normal (304).jpeg',
#  'Normal (304).png',
#  'Normal (305).jpeg',
#  'Normal (305).png',
#  'Normal (306).jpeg',
#  'Normal (306).png',
#  'Normal (307).jpeg',
#  'Normal (307).png',
#  'Normal (308).jpeg',
#  'Normal (308).png',
#  'Normal (309).jpeg',
#  'Normal (309).png',
#  'Normal (31).jpeg',
#  'Normal (31).png',
#  'Normal (310).jpeg',
#  'Normal (310).png',
#  'Normal (311).jpeg',
#  'Normal (311).png',
#  'Normal (312).jpeg',
#  'Normal (312).png',
#  'Normal (313).jpeg',
#  'Normal (313).png',
#  'Normal (314).jpeg',
#  'Normal (314).png',
#  'Normal (315).jpeg',
#  'Normal (315).png',
#  'Normal (316).jpeg',
#  'Normal (316).png',
#  'Normal (317).jpeg',
#  'Normal (317).png',
#  'Normal (318).jpeg',
#  'Normal (318).png',
#  'Normal (319).jpeg',
#  'Normal (319).png',
#  'Normal (32).jpeg',
#  'Normal (32).png',
#  'Normal (320).jpeg',
#  'Normal (320).png',
#  'Normal (321).jpeg',
#  'Normal (321).png',
#  'Normal (322).jpeg',
#  'Normal (322).png',
#  ...]

# %%
# 肺部感染的图片
files_covid_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'Covid19'))
files_covid_pneumonia
# Out:
# ['covid19 (1).jpeg',
#  'covid19 (1).jpg',
#  'covid19 (1).png',
#  'covid19 (10).jpeg',
#  'covid19 (10).jpg',
#  'covid19 (10).png',
#  'covid19 (100).jpg',
#  'covid19 (100).png',
#  'covid19 (1000).png',
#  'covid19 (1001).png',
#  'covid19 (1002).png',
#  'covid19 (1003).png',
#  'covid19 (1004).png',
#  'covid19 (1005).png',
#  'covid19 (1006).png',
#  'covid19 (1007).png',
#  'covid19 (1008).png',
#  'covid19 (1009).png',
#  'covid19 (101).jpg',
#  'covid19 (101).png',
#  'covid19 (1010).png',
#  'covid19 (1011).png',
#  'covid19 (1012).png',
#  'covid19 (1013).png',
#  'covid19 (1014).png',
#  'covid19 (1015).png',
#  'covid19 (1016).png',
#  'covid19 (1017).png',
#  'covid19 (1018).png',
#  'covid19 (1019).png',
#  'covid19 (102).jpg',
#  'covid19 (102).png',
#  'covid19 (1020).png',
#  'covid19 (1021).png',
#  'covid19 (1022).png',
#  'covid19 (1023).png',
#  'covid19 (1024).png',
#  'covid19 (1025).png',
#  'covid19 (1026).png',
#  'covid19 (1027).png',
#  'covid19 (1028).png',
#  'covid19 (1029).png',
#  'covid19 (103).jpg',
#  'covid19 (103).png',
#  'covid19 (1030).png',
#  'covid19 (1031).png',
#  'covid19 (1032).png',
#  'covid19 (1033).png',
#  'covid19 (1034).png',
#  'covid19 (1035).png',
#  'covid19 (1036).png',
#  'covid19 (1037).png',
#  'covid19 (1038).png',
#  'covid19 (1039).png',
#  'covid19 (104).jpg',
#  'covid19 (104).png',
#  'covid19 (1040).png',
#  'covid19 (1041).png',
#  'covid19 (1042).png',
#  'covid19 (1043).png',
#  'covid19 (1044).png',
#  'covid19 (1045).png',
#  'covid19 (1046).png',
#  'covid19 (1047).png',
#  'covid19 (1048).png',
#  'covid19 (1049).png',
#  'covid19 (105).jpg',
#  'covid19 (105).png',
#  'covid19 (1050).png',
#  'covid19 (1051).png',
#  'covid19 (1052).png',
#  'covid19 (1053).png',
#  'covid19 (1054).png',
#  'covid19 (1055).png',
#  'covid19 (1056).png',
#  'covid19 (1057).png',
#  'covid19 (1058).png',
#  'covid19 (1059).png',
#  'covid19 (106).jpg',
#  'covid19 (106).png',
#  'covid19 (1060).png',
#  'covid19 (1061).png',
#  'covid19 (1062).png',
#  'covid19 (1063).png',
#  'covid19 (1064).png',
#  'covid19 (1065).png',
#  'covid19 (1066).png',
#  'covid19 (1067).png',
#  'covid19 (1068).png',
#  'covid19 (1069).png',
#  'covid19 (107).jpg',
#  'covid19 (107).png',
#  'covid19 (1070).png',
#  'covid19 (1071).png',
#  'covid19 (1072).png',
#  'covid19 (1073).png',
#  'covid19 (1074).png',
#  'covid19 (1075).png',
#  'covid19 (1076).png',
#  'covid19 (1077).png',
#  'covid19 (1078).png',
#  'covid19 (1079).png',
#  'covid19 (108).jpg',
#  'covid19 (108).png',
#  'covid19 (1080).png',
#  'covid19 (1081).png',
#  'covid19 (1082).png',
#  'covid19 (1083).png',
#  'covid19 (1084).png',
#  'covid19 (1085).png',
#  'covid19 (1086).png',
#  'covid19 (1087).png',
#  'covid19 (1088).png',
#  'covid19 (1089).png',
#  'covid19 (109).jpg',
#  'covid19 (109).png',
#  'covid19 (1090).png',
#  'covid19 (1091).png',
#  'covid19 (1092).png',
#  'covid19 (1093).png',
#  'covid19 (1094).png',
#  'covid19 (1095).png',
#  'covid19 (1096).png',
#  'covid19 (1097).png',
#  'covid19 (1098).png',
#  'covid19 (1099).png',
#  'covid19 (11).jpeg',
#  'covid19 (11).jpg',
#  'covid19 (11).png',
#  'covid19 (110).jpg',
#  'covid19 (110).png',
#  'covid19 (1100).png',
#  'covid19 (1101).png',
#  'covid19 (1102).png',
#  'covid19 (1103).png',
#  'covid19 (1104).png',
#  'covid19 (1105).png',
#  'covid19 (1106).png',
#  'covid19 (1107).png',
#  'covid19 (1108).png',
#  'covid19 (1109).png',
#  'covid19 (111).jpg',
#  'covid19 (111).png',
#  'covid19 (1110).png',
#  'covid19 (1111).png',
#  'covid19 (1112).png',
#  'covid19 (1113).png',
#  'covid19 (1114).png',
#  'covid19 (1115).png',
#  'covid19 (1116).png',
#  'covid19 (1117).png',
#  'covid19 (1118).png',
#  'covid19 (1119).png',
#  'covid19 (112).jpg',
#  'covid19 (112).png',
#  'covid19 (1120).png',
#  'covid19 (1121).png',
#  'covid19 (1122).png',
#  'covid19 (1123).png',
#  'covid19 (1124).png',
#  'covid19 (1125).png',
#  'covid19 (1126).png',
#  'covid19 (1127).png',
#  'covid19 (1128).png',
#  'covid19 (1129).png',
#  'covid19 (113).jpg',
#  'covid19 (113).png',
#  'covid19 (1130).png',
#  'covid19 (1131).png',
#  'covid19 (1132).png',
#  'covid19 (1133).png',
#  'covid19 (1134).png',
#  'covid19 (1135).png',
#  'covid19 (1136).png',
#  'covid19 (1137).png',
#  'covid19 (1138).png',
#  'covid19 (1139).png',
#  'covid19 (114).jpg',
#  'covid19 (114).png',
#  'covid19 (1140).png',
#  'covid19 (1141).png',
#  'covid19 (1142).png',
#  'covid19 (1143).png',
#  'covid19 (1144).png',
#  'covid19 (1145).png',
#  'covid19 (1146).png',
#  'covid19 (1147).png',
#  'covid19 (1148).png',
#  'covid19 (1149).png',
#  'covid19 (115).jpg',
#  'covid19 (115).png',
#  'covid19 (1150).png',
#  'covid19 (1151).png',
#  'covid19 (1152).png',
#  'covid19 (1153).png',
#  'covid19 (1154).png',
#  'covid19 (1155).png',
#  'covid19 (1156).png',
#  'covid19 (1157).png',
#  'covid19 (1158).png',
#  'covid19 (1159).png',
#  'covid19 (116).jpg',
#  'covid19 (116).png',
#  'covid19 (1160).png',
#  'covid19 (1161).png',
#  'covid19 (1162).png',
#  'covid19 (1163).png',
#  'covid19 (1164).png',
#  'covid19 (1165).png',
#  'covid19 (1166).png',
#  'covid19 (1167).png',
#  'covid19 (1168).png',
#  'covid19 (1169).png',
#  'covid19 (117).jpg',
#  'covid19 (117).png',
#  'covid19 (1170).png',
#  'covid19 (1171).png',
#  'covid19 (1172).png',
#  'covid19 (1173).png',
#  'covid19 (1174).png',
#  'covid19 (1175).png',
#  'covid19 (1176).png',
#  'covid19 (1177).png',
#  'covid19 (1178).png',
#  'covid19 (1179).png',
#  'covid19 (118).jpg',
#  'covid19 (118).png',
#  'covid19 (1180).png',
#  'covid19 (1181).png',
#  'covid19 (1182).png',
#  'covid19 (1183).png',
#  'covid19 (1184).png',
#  'covid19 (1185).png',
#  'covid19 (1186).png',
#  'covid19 (1187).png',
#  'covid19 (1188).png',
#  'covid19 (1189).png',
#  'covid19 (119).jpg',
#  'covid19 (119).png',
#  'covid19 (1190).png',
#  'covid19 (1191).png',
#  'covid19 (1192).png',
#  'covid19 (1193).png',
#  'covid19 (1194).png',
#  'covid19 (1195).png',
#  'covid19 (1196).png',
#  'covid19 (1197).png',
#  'covid19 (1198).png',
#  'covid19 (1199).png',
#  'covid19 (12).jpeg',
#  'covid19 (12).jpg',
#  'covid19 (12).png',
#  'covid19 (120).jpg',
#  'covid19 (120).png',
#  'covid19 (1200).png',
#  'covid19 (1201).png',
#  'covid19 (1202).png',
#  'covid19 (1203).png',
#  'covid19 (1204).png',
#  'covid19 (1205).png',
#  'covid19 (1206).png',
#  'covid19 (1207).png',
#  'covid19 (1208).png',
#  'covid19 (1209).png',
#  'covid19 (121).jpg',
#  'covid19 (121).png',
#  'covid19 (1210).png',
#  'covid19 (1211).png',
#  'covid19 (1212).png',
#  'covid19 (1213).png',
#  'covid19 (1214).png',
#  'covid19 (1215).png',
#  'covid19 (1216).png',
#  'covid19 (1217).png',
#  'covid19 (1218).png',
#  'covid19 (1219).png',
#  'covid19 (122).jpg',
#  'covid19 (122).png',
#  'covid19 (1220).png',
#  'covid19 (1221).png',
#  'covid19 (1222).png',
#  'covid19 (1223).png',
#  'covid19 (1224).png',
#  'covid19 (1225).png',
#  'covid19 (1226).png',
#  'covid19 (1227).png',
#  'covid19 (1228).png',
#  'covid19 (1229).png',
#  'covid19 (123).jpg',
#  'covid19 (123).png',
#  'covid19 (1230).png',
#  'covid19 (1231).png',
#  'covid19 (1232).png',
#  'covid19 (1233).png',
#  'covid19 (1234).png',
#  'covid19 (1235).png',
#  'covid19 (1236).png',
#  'covid19 (1237).png',
#  'covid19 (1238).png',
#  'covid19 (1239).png',
#  'covid19 (124).jpg',
#  'covid19 (124).png',
#  'covid19 (1240).png',
#  'covid19 (1241).png',
#  'covid19 (1242).png',
#  'covid19 (1243).png',
#  'covid19 (1244).png',
#  'covid19 (1245).png',
#  'covid19 (1246).png',
#  'covid19 (1247).png',
#  'covid19 (1248).png',
#  'covid19 (1249).png',
#  'covid19 (125).jpg',
#  'covid19 (125).png',
#  'covid19 (1250).png',
#  'covid19 (1251).png',
#  'covid19 (1252).png',
#  'covid19 (1253).png',
#  'covid19 (1254).png',
#  'covid19 (1255).png',
#  'covid19 (1256).png',
#  'covid19 (1257).png',
#  'covid19 (1258).png',
#  'covid19 (1259).png',
#  'covid19 (126).jpg',
#  'covid19 (126).png',
#  'covid19 (1260).png',
#  'covid19 (1261).png',
#  'covid19 (1262).png',
#  'covid19 (1263).png',
#  'covid19 (1264).png',
#  'covid19 (1265).png',
#  'covid19 (1266).png',
#  'covid19 (1267).png',
#  'covid19 (1268).png',
#  'covid19 (1269).png',
#  'covid19 (127).jpg',
#  'covid19 (127).png',
#  'covid19 (1270).png',
#  'covid19 (1271).png',
#  'covid19 (1272).png',
#  'covid19 (1273).png',
#  'covid19 (1274).png',
#  'covid19 (1275).png',
#  'covid19 (1276).png',
#  'covid19 (1277).png',
#  'covid19 (1278).png',
#  'covid19 (1279).png',
#  'covid19 (128).jpg',
#  'covid19 (128).png',
#  'covid19 (1280).png',
#  'covid19 (1281).png',
#  'covid19 (1282).png',
#  'covid19 (1283).png',
#  'covid19 (1284).png',
#  'covid19 (1285).png',
#  'covid19 (1286).png',
#  'covid19 (1287).png',
#  'covid19 (1288).png',
#  'covid19 (1289).png',
#  'covid19 (129).jpg',
#  'covid19 (129).png',
#  'covid19 (1290).png',
#  'covid19 (1291).png',
#  'covid19 (1292).png',
#  'covid19 (1293).png',
#  'covid19 (1294).png',
#  'covid19 (1295).png',
#  'covid19 (1296).png',
#  'covid19 (1297).png',
#  'covid19 (1298).png',
#  'covid19 (1299).png',
#  'covid19 (13).jpeg',
#  'covid19 (13).jpg',
#  'covid19 (13).png',
#  'covid19 (130).jpg',
#  'covid19 (130).png',
#  'covid19 (1300).png',
#  'covid19 (1301).png',
#  'covid19 (1302).png',
#  'covid19 (1303).png',
#  'covid19 (1304).png',
#  'covid19 (1305).png',
#  'covid19 (1306).png',
#  'covid19 (1307).png',
#  'covid19 (1308).png',
#  'covid19 (1309).png',
#  'covid19 (131).jpg',
#  'covid19 (131).png',
#  'covid19 (1310).png',
#  'covid19 (1311).png',
#  'covid19 (1312).png',
#  'covid19 (1313).png',
#  'covid19 (1314).png',
#  'covid19 (1315).png',
#  'covid19 (1316).png',
#  'covid19 (1317).png',
#  'covid19 (1318).png',
#  'covid19 (1319).png',
#  'covid19 (132).jpg',
#  'covid19 (132).png',
#  'covid19 (1320).png',
#  'covid19 (1321).png',
#  'covid19 (1322).png',
#  'covid19 (1323).png',
#  'covid19 (1324).png',
#  'covid19 (1325).png',
#  'covid19 (1326).png',
#  'covid19 (1327).png',
#  'covid19 (1328).png',
#  'covid19 (1329).png',
#  'covid19 (133).jpg',
#  'covid19 (133).png',
#  'covid19 (1330).png',
#  'covid19 (1331).png',
#  'covid19 (1332).png',
#  'covid19 (1333).png',
#  'covid19 (1334).png',
#  'covid19 (1335).png',
#  'covid19 (1336).png',
#  'covid19 (1337).png',
#  'covid19 (1338).png',
#  'covid19 (1339).png',
#  'covid19 (134).jpg',
#  'covid19 (134).png',
#  'covid19 (1340).png',
#  'covid19 (1341).png',
#  'covid19 (1342).png',
#  'covid19 (1343).png',
#  'covid19 (1344).png',
#  'covid19 (1345).png',
#  'covid19 (1346).png',
#  'covid19 (1347).png',
#  'covid19 (1348).png',
#  'covid19 (1349).png',
#  'covid19 (135).jpg',
#  'covid19 (135).png',
#  'covid19 (1350).png',
#  'covid19 (1351).png',
#  'covid19 (1352).png',
#  'covid19 (1353).png',
#  'covid19 (1354).png',
#  'covid19 (1355).png',
#  'covid19 (1356).png',
#  'covid19 (1357).png',
#  'covid19 (1358).png',
#  'covid19 (1359).png',
#  'covid19 (136).jpg',
#  'covid19 (136).png',
#  'covid19 (1360).png',
#  'covid19 (1361).png',
#  'covid19 (1362).png',
#  'covid19 (1363).png',
#  'covid19 (1364).png',
#  'covid19 (1365).png',
#  'covid19 (1366).png',
#  'covid19 (1367).png',
#  'covid19 (1368).png',
#  'covid19 (1369).png',
#  'covid19 (137).jpg',
#  'covid19 (137).png',
#  'covid19 (1370).png',
#  'covid19 (1371).png',
#  'covid19 (1372).png',
#  'covid19 (1373).png',
#  'covid19 (1374).png',
#  'covid19 (1375).png',
#  'covid19 (1376).png',
#  'covid19 (1377).png',
#  'covid19 (1378).png',
#  'covid19 (1379).png',
#  'covid19 (138).jpg',
#  'covid19 (138).png',
#  'covid19 (1380).png',
#  'covid19 (1381).png',
#  'covid19 (1382).png',
#  'covid19 (1383).png',
#  'covid19 (1384).png',
#  'covid19 (1385).png',
#  'covid19 (1386).png',
#  'covid19 (1387).png',
#  'covid19 (1388).png',
#  'covid19 (1389).png',
#  'covid19 (139).jpg',
#  'covid19 (139).png',
#  'covid19 (1390).png',
#  'covid19 (1391).png',
#  'covid19 (1392).png',
#  'covid19 (1393).png',
#  'covid19 (1394).png',
#  'covid19 (1395).png',
#  'covid19 (1396).png',
#  'covid19 (1397).png',
#  'covid19 (1398).png',
#  'covid19 (1399).png',
#  'covid19 (14).jpeg',
#  'covid19 (14).jpg',
#  'covid19 (14).png',
#  'covid19 (140).jpg',
#  'covid19 (140).png',
#  'covid19 (1400).png',
#  'covid19 (1401).png',
#  'covid19 (1402).png',
#  'covid19 (1403).png',
#  'covid19 (1404).png',
#  'covid19 (1405).png',
#  'covid19 (1406).png',
#  'covid19 (1407).png',
#  'covid19 (1408).png',
#  'covid19 (1409).png',
#  'covid19 (141).jpg',
#  'covid19 (141).png',
#  'covid19 (1410).png',
#  'covid19 (1411).png',
#  'covid19 (1412).png',
#  'covid19 (1413).png',
#  'covid19 (1414).png',
#  'covid19 (1415).png',
#  'covid19 (1416).png',
#  'covid19 (1417).png',
#  'covid19 (1418).png',
#  'covid19 (1419).png',
#  'covid19 (142).jpg',
#  'covid19 (142).png',
#  'covid19 (1420).png',
#  'covid19 (1421).png',
#  'covid19 (1422).png',
#  'covid19 (1423).png',
#  'covid19 (1424).png',
#  'covid19 (1425).png',
#  'covid19 (1426).png',
#  'covid19 (1427).png',
#  'covid19 (1428).png',
#  'covid19 (1429).png',
#  'covid19 (143).jpg',
#  'covid19 (143).png',
#  'covid19 (1430).png',
#  'covid19 (1431).png',
#  'covid19 (1432).png',
#  'covid19 (1433).png',
#  'covid19 (1434).png',
#  'covid19 (1435).png',
#  'covid19 (1436).png',
#  'covid19 (1437).png',
#  'covid19 (1438).png',
#  'covid19 (1439).png',
#  'covid19 (144).jpg',
#  'covid19 (144).png',
#  'covid19 (1440).png',
#  'covid19 (1441).png',
#  'covid19 (1442).png',
#  'covid19 (1443).png',
#  'covid19 (1444).png',
#  'covid19 (1445).png',
#  'covid19 (1446).png',
#  'covid19 (1447).png',
#  'covid19 (1448).png',
#  'covid19 (1449).png',
#  'covid19 (145).jpg',
#  'covid19 (145).png',
#  'covid19 (1450).png',
#  'covid19 (1451).png',
#  'covid19 (1452).png',
#  'covid19 (1453).png',
#  'covid19 (1454).png',
#  'covid19 (1455).png',
#  'covid19 (1456).png',
#  'covid19 (1457).png',
#  'covid19 (1458).png',
#  'covid19 (1459).png',
#  'covid19 (146).jpg',
#  'covid19 (146).png',
#  'covid19 (1460).png',
#  'covid19 (1461).png',
#  'covid19 (1462).png',
#  'covid19 (1463).png',
#  'covid19 (1464).png',
#  'covid19 (1465).png',
#  'covid19 (1466).png',
#  'covid19 (1467).png',
#  'covid19 (1468).png',
#  'covid19 (1469).png',
#  'covid19 (147).jpg',
#  'covid19 (147).png',
#  'covid19 (1470).png',
#  'covid19 (1471).png',
#  'covid19 (1472).png',
#  'covid19 (1473).png',
#  'covid19 (1474).png',
#  'covid19 (1475).png',
#  'covid19 (1476).png',
#  'covid19 (1477).png',
#  'covid19 (1478).png',
#  'covid19 (1479).png',
#  'covid19 (148).jpg',
#  'covid19 (148).png',
#  'covid19 (1480).png',
#  'covid19 (1481).png',
#  'covid19 (1482).png',
#  'covid19 (1483).png',
#  'covid19 (1484).png',
#  'covid19 (1485).png',
#  'covid19 (1486).png',
#  'covid19 (1487).png',
#  'covid19 (1488).png',
#  'covid19 (1489).png',
#  'covid19 (149).jpg',
#  'covid19 (149).png',
#  'covid19 (1490).png',
#  'covid19 (1491).png',
#  'covid19 (1492).png',
#  'covid19 (1493).png',
#  'covid19 (1494).png',
#  'covid19 (1495).png',
#  'covid19 (1496).png',
#  'covid19 (1497).png',
#  'covid19 (1498).png',
#  'covid19 (1499).png',
#  'covid19 (15).jpeg',
#  'covid19 (15).jpg',
#  'covid19 (15).png',
#  'covid19 (150).jpg',
#  'covid19 (150).png',
#  'covid19 (1500).png',
#  'covid19 (1501).png',
#  'covid19 (1502).png',
#  'covid19 (1503).png',
#  'covid19 (1504).png',
#  'covid19 (1505).png',
#  'covid19 (1506).png',
#  'covid19 (1507).png',
#  'covid19 (1508).png',
#  'covid19 (1509).png',
#  'covid19 (151).jpg',
#  'covid19 (151).png',
#  'covid19 (1510).png',
#  'covid19 (1511).png',
#  'covid19 (1512).png',
#  'covid19 (1513).png',
#  'covid19 (1514).png',
#  'covid19 (1515).png',
#  'covid19 (1516).png',
#  'covid19 (1517).png',
#  'covid19 (1518).png',
#  'covid19 (1519).png',
#  'covid19 (152).jpg',
#  'covid19 (152).png',
#  'covid19 (1520).png',
#  'covid19 (1521).png',
#  'covid19 (1522).png',
#  'covid19 (1523).png',
#  'covid19 (1524).png',
#  'covid19 (1525).png',
#  'covid19 (1526).png',
#  'covid19 (1527).png',
#  'covid19 (1528).png',
#  'covid19 (1529).png',
#  'covid19 (153).jpg',
#  'covid19 (153).png',
#  'covid19 (1530).png',
#  'covid19 (1531).png',
#  'covid19 (1532).png',
#  'covid19 (1533).png',
#  'covid19 (1534).png',
#  'covid19 (1535).png',
#  'covid19 (1536).png',
#  'covid19 (1537).png',
#  'covid19 (1538).png',
#  'covid19 (1539).png',
#  'covid19 (154).jpg',
#  'covid19 (154).png',
#  'covid19 (1540).png',
#  'covid19 (1541).png',
#  'covid19 (1542).png',
#  'covid19 (1543).png',
#  'covid19 (1544).png',
#  'covid19 (1545).png',
#  'covid19 (1546).png',
#  'covid19 (1547).png',
#  'covid19 (1548).png',
#  'covid19 (1549).png',
#  'covid19 (155).jpg',
#  'covid19 (155).png',
#  'covid19 (1550).png',
#  'covid19 (1551).png',
#  'covid19 (1552).png',
#  'covid19 (1553).png',
#  'covid19 (1554).png',
#  'covid19 (1555).png',
#  'covid19 (1556).png',
#  'covid19 (1557).png',
#  'covid19 (1558).png',
#  'covid19 (1559).png',
#  'covid19 (156).jpg',
#  'covid19 (156).png',
#  'covid19 (1560).png',
#  'covid19 (1561).png',
#  'covid19 (1562).png',
#  'covid19 (1563).png',
#  'covid19 (1564).png',
#  'covid19 (1565).png',
#  'covid19 (1566).png',
#  'covid19 (1567).png',
#  'covid19 (1568).png',
#  'covid19 (1569).png',
#  'covid19 (157).jpg',
#  'covid19 (157).png',
#  'covid19 (1570).png',
#  'covid19 (1571).png',
#  'covid19 (1572).png',
#  'covid19 (1573).png',
#  'covid19 (1574).png',
#  'covid19 (1575).png',
#  'covid19 (1576).png',
#  'covid19 (1577).png',
#  'covid19 (1578).png',
#  'covid19 (1579).png',
#  'covid19 (158).jpg',
#  'covid19 (158).png',
#  'covid19 (1580).png',
#  'covid19 (1581).png',
#  'covid19 (1582).png',
#  'covid19 (1583).png',
#  'covid19 (1584).png',
#  'covid19 (1585).png',
#  'covid19 (1586).png',
#  'covid19 (1587).png',
#  'covid19 (1588).png',
#  'covid19 (1589).png',
#  'covid19 (159).jpg',
#  'covid19 (159).png',
#  'covid19 (1590).png',
#  'covid19 (1591).png',
#  'covid19 (1592).png',
#  'covid19 (1593).png',
#  'covid19 (1594).png',
#  'covid19 (1595).png',
#  'covid19 (1596).png',
#  'covid19 (1597).png',
#  'covid19 (1598).png',
#  'covid19 (1599).png',
#  'covid19 (16).jpeg',
#  'covid19 (16).jpg',
#  'covid19 (16).png',
#  'covid19 (160).jpg',
#  'covid19 (160).png',
#  'covid19 (1600).png',
#  'covid19 (1601).png',
#  'covid19 (1602).png',
#  'covid19 (1603).png',
#  'covid19 (1604).png',
#  'covid19 (1605).png',
#  'covid19 (1606).png',
#  'covid19 (1607).png',
#  'covid19 (1608).png',
#  'covid19 (1609).png',
#  'covid19 (161).jpg',
#  'covid19 (161).png',
#  'covid19 (1610).png',
#  'covid19 (1611).png',
#  'covid19 (1612).png',
#  'covid19 (1613).png',
#  'covid19 (1614).png',
#  'covid19 (1615).png',
#  'covid19 (1616).png',
#  'covid19 (1617).png',
#  'covid19 (1618).png',
#  'covid19 (1619).png',
#  'covid19 (162).jpg',
#  'covid19 (162).png',
#  'covid19 (1620).png',
#  'covid19 (1621).png',
#  'covid19 (1622).png',
#  'covid19 (1623).png',
#  'covid19 (1624).png',
#  'covid19 (1625).png',
#  'covid19 (1626).png',
#  'covid19 (1627).png',
#  'covid19 (1628).png',
#  'covid19 (1629).png',
#  'covid19 (163).jpg',
#  'covid19 (163).png',
#  'covid19 (1630).png',
#  'covid19 (1631).png',
#  'covid19 (1632).png',
#  'covid19 (1633).png',
#  'covid19 (1634).png',
#  'covid19 (1635).png',
#  'covid19 (1636).png',
#  'covid19 (1637).png',
#  'covid19 (1638).png',
#  'covid19 (1639).png',
#  'covid19 (164).jpg',
#  'covid19 (164).png',
#  'covid19 (1640).png',
#  'covid19 (1641).png',
#  'covid19 (1642).png',
#  'covid19 (1643).png',
#  'covid19 (1644).png',
#  'covid19 (1645).png',
#  'covid19 (1646).png',
#  'covid19 (1647).png',
#  'covid19 (1648).png',
#  'covid19 (1649).png',
#  'covid19 (165).jpg',
#  'covid19 (165).png',
#  'covid19 (1650).png',
#  'covid19 (1651).png',
#  'covid19 (1652).png',
#  'covid19 (1653).png',
#  'covid19 (1654).png',
#  'covid19 (1655).png',
#  'covid19 (1656).png',
#  'covid19 (1657).png',
#  'covid19 (1658).png',
#  'covid19 (1659).png',
#  'covid19 (166).jpg',
#  'covid19 (166).png',
#  'covid19 (1660).png',
#  'covid19 (1661).png',
#  'covid19 (1662).png',
#  'covid19 (1663).png',
#  'covid19 (1664).png',
#  'covid19 (1665).png',
#  'covid19 (1666).png',
#  'covid19 (1667).png',
#  'covid19 (1668).png',
#  'covid19 (1669).png',
#  'covid19 (167).jpg',
#  'covid19 (167).png',
#  'covid19 (1670).png',
#  'covid19 (1671).png',
#  'covid19 (1672).png',
#  'covid19 (1673).png',
#  'covid19 (1674).png',
#  'covid19 (1675).png',
#  'covid19 (1676).png',
#  'covid19 (1677).png',
#  'covid19 (1678).png',
#  'covid19 (1679).png',
#  'covid19 (168).jpg',
#  'covid19 (168).png',
#  'covid19 (1680).png',
#  'covid19 (1681).png',
#  'covid19 (1682).png',
#  'covid19 (1683).png',
#  'covid19 (1684).png',
#  'covid19 (1685).png',
#  'covid19 (1686).png',
#  'covid19 (1687).png',
#  'covid19 (1688).png',
#  'covid19 (1689).png',
#  'covid19 (169).jpg',
#  'covid19 (169).png',
#  'covid19 (1690).png',
#  'covid19 (1691).png',
#  'covid19 (1692).png',
#  'covid19 (1693).png',
#  'covid19 (1694).png',
#  'covid19 (1695).png',
#  'covid19 (1696).png',
#  'covid19 (1697).png',
#  'covid19 (1698).png',
#  'covid19 (1699).png',
#  'covid19 (17).jpeg',
#  'covid19 (17).jpg',
#  'covid19 (17).png',
#  'covid19 (170).jpg',
#  'covid19 (170).png',
#  'covid19 (1700).png',
#  'covid19 (1701).png',
#  'covid19 (1702).png',
#  'covid19 (1703).png',
#  'covid19 (1704).png',
#  'covid19 (1705).png',
#  'covid19 (1706).png',
#  'covid19 (1707).png',
#  'covid19 (1708).png',
#  'covid19 (1709).png',
#  'covid19 (171).jpg',
#  'covid19 (171).png',
#  'covid19 (1710).png',
#  'covid19 (1711).png',
#  'covid19 (1712).png',
#  'covid19 (1713).png',
#  'covid19 (1714).png',
#  'covid19 (1715).png',
#  'covid19 (1716).png',
#  'covid19 (1717).png',
#  'covid19 (1718).png',
#  'covid19 (1719).png',
#  'covid19 (172).jpg',
#  'covid19 (172).png',
#  'covid19 (1720).png',
#  'covid19 (1721).png',
#  'covid19 (1722).png',
#  'covid19 (1723).png',
#  'covid19 (1724).png',
#  'covid19 (1725).png',
#  'covid19 (1726).png',
#  'covid19 (1727).png',
#  'covid19 (1728).png',
#  'covid19 (1729).png',
#  'covid19 (173).jpg',
#  'covid19 (173).png',
#  'covid19 (1730).png',
#  'covid19 (1731).png',
#  'covid19 (1732).png',
#  'covid19 (1733).png',
#  'covid19 (1734).png',
#  'covid19 (1735).png',
#  'covid19 (1736).png',
#  'covid19 (1737).png',
#  'covid19 (1738).png',
#  'covid19 (1739).png',
#  'covid19 (174).jpg',
#  'covid19 (174).png',
#  'covid19 (1740).png',
#  'covid19 (1741).png',
#  'covid19 (1742).png',
#  'covid19 (1743).png',
#  'covid19 (1744).png',
#  'covid19 (1745).png',
#  'covid19 (1746).png',
#  'covid19 (1747).png',
#  'covid19 (1748).png',
#  'covid19 (1749).png',
#  'covid19 (175).jpg',
#  'covid19 (175).png',
#  'covid19 (1750).png',
#  'covid19 (1751).png',
#  'covid19 (1752).png',
#  'covid19 (1753).png',
#  'covid19 (1754).png',
#  'covid19 (1755).png',
#  'covid19 (1756).png',
#  'covid19 (1757).png',
#  'covid19 (1758).png',
#  'covid19 (1759).png',
#  'covid19 (176).jpg',
#  'covid19 (176).png',
#  'covid19 (1760).png',
#  'covid19 (1761).png',
#  'covid19 (1762).png',
#  'covid19 (1763).png',
#  'covid19 (1764).png',
#  'covid19 (1765).png',
#  'covid19 (1766).png',
#  'covid19 (1767).png',
#  'covid19 (1768).png',
#  'covid19 (1769).png',
#  'covid19 (177).jpg',
#  'covid19 (177).png',
#  'covid19 (1770).png',
#  'covid19 (1771).png',
#  'covid19 (1772).png',
#  'covid19 (1773).png',
#  'covid19 (1774).png',
#  'covid19 (1775).png',
#  'covid19 (1776).png',
#  'covid19 (1777).png',
#  'covid19 (1778).png',
#  'covid19 (1779).png',
#  'covid19 (178).jpg',
#  'covid19 (178).png',
#  'covid19 (1780).png',
#  'covid19 (1781).png',
#  'covid19 (1782).png',
#  'covid19 (1783).png',
#  'covid19 (1784).png',
#  'covid19 (1785).png',
#  'covid19 (1786).png',
#  'covid19 (1787).png',
#  'covid19 (1788).png',
#  'covid19 (1789).png',
#  'covid19 (179).jpg',
#  'covid19 (179).png',
#  'covid19 (1790).png',
#  'covid19 (1791).png',
#  'covid19 (1792).png',
#  'covid19 (1793).png',
#  'covid19 (1794).png',
#  'covid19 (1795).png',
#  'covid19 (1796).png',
#  'covid19 (1797).png',
#  'covid19 (1798).png',
#  'covid19 (1799).png',
#  'covid19 (18).jpeg',
#  'covid19 (18).jpg',
#  'covid19 (18).png',
#  'covid19 (180).jpg',
#  'covid19 (180).png',
#  'covid19 (1800).png',
#  'covid19 (1801).png',
#  'covid19 (1802).png',
#  'covid19 (1803).png',
#  'covid19 (1804).png',
#  'covid19 (1805).png',
#  'covid19 (1806).png',
#  'covid19 (1807).png',
#  ...]

# %%
# val 简介
dataloaders['val'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 700
#     Root location: covidNormal/val/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# test 简介
dataloaders['test'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1400
#     Root location: covidNormal/test/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# ### 提示：需要安装库：tb-nightly
# ### pip3 install tb-nightly

# %%
# 导入SummaryWriter
from torch.utils.tensorboard import SummaryWriter
# SummaryWriter() 向事件文件写入事件和概要

# 定义日志路径
log_path = 'logdir2/'

# 定义函数：获取tensorboard writer
def tb_writer():
    timestr = time.strftime("%Y%m%d_%H%M%S") # 时间格式
    writer = SummaryWriter(log_path+timestr) # 写入日志
    return writer


writer = tb_writer()

# 第1种方法：显示部分图片集
images, labels = next(iter(dataloaders['train'])) # 获取到一批数据

# 定义图片显示方法
def imshow(img):
    img = img / 2 + 0.5 # 逆正则化
    np_img = img.numpy() # tensor --> numpy
    plt.imshow(np.transpose(np_img, (1, 2, 0))) # 改变通道顺序
    plt.show()
    
grid = utils.make_grid(images) # make_grid的作用是将若干幅图像拼成一幅图像
imshow(grid) # 展示图片

# 在summary中添加图片数据
writer.add_image('X-Ray grid', grid, 0) # add_image(tag, img_tensor, global_step=None, walltime=None, dataformats='CHW')

writer.flush() # 把事件文件写入到磁盘
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 获取一张图片tensor
dataloaders['train'].dataset[4] # 返回：tensor, label
# Out:
# (tensor([[[-0.5253, -0.5424, -0.5596,  ..., -0.4226, -0.5082, -0.6281],
#           [-0.5082, -0.5082, -0.5082,  ..., -0.7479, -0.8335, -0.9363],
#           [-0.4911, -0.4568, -0.4568,  ..., -0.8507, -0.9192, -0.9534],
#           ...,
#           [-0.1314, -0.1143, -0.0972,  ...,  0.0741,  0.0741,  0.0569],
#           [-0.1486, -0.1143, -0.0972,  ...,  0.0912,  0.0741,  0.0741],
#           [-0.1486, -0.1143, -0.0972,  ...,  0.0912,  0.0912,  0.0569]],
#
#          [[-0.4076, -0.4251, -0.4426,  ..., -0.3025, -0.3901, -0.5126],
#           [-0.3901, -0.3901, -0.3901,  ..., -0.6352, -0.7227, -0.8277],
#           [-0.3725, -0.3375, -0.3375,  ..., -0.7402, -0.8102, -0.8452],
#           ...,
#           [-0.0049,  0.0126,  0.0301,  ...,  0.2052,  0.2052,  0.1877],
#           [-0.0224,  0.0126,  0.0301,  ...,  0.2227,  0.2052,  0.2052],
#           [-0.0224,  0.0126,  0.0301,  ...,  0.2227,  0.2227,  0.1877]],
#
#          [[-0.1835, -0.2010, -0.2184,  ..., -0.0790, -0.1661, -0.2881],
#           [-0.1661, -0.1661, -0.1661,  ..., -0.4101, -0.4973, -0.6018],
#           [-0.1487, -0.1138, -0.1138,  ..., -0.5147, -0.5844, -0.6193],
#           ...,
#           [ 0.2173,  0.2348,  0.2522,  ...,  0.4265,  0.4265,  0.4091],
#           [ 0.1999,  0.2348,  0.2522,  ...,  0.4439,  0.4265,  0.4265],
#           [ 0.1999,  0.2348,  0.2522,  ...,  0.4439,  0.4439,  0.4091]]]),
#  0)

# %%
# 第2种方法：显示一张图片
def show_sample(img, label):
    print("Label : ", dataloaders['train'].dataset.classes[label]) # 输出标签
    img = img.numpy().transpose((1, 2, 0)) # 改变shape顺序
    mean = np.array([0.485, 0.456, 0.406]) # 均值
    std = np.array([0.229, 0.224, 0.225]) # 标准差
    img = img * std + mean # 逆向复原
    img = np.clip(img, 0, 1) # np.clip() 将inp中的元素值限制在(0,1)之间，最小值为0，最大值为1。小于min的等于min，大于max等于max
    plt.imshow(img)
    plt.axis('off') # 关闭坐标轴

show_sample(*dataloaders['train'].dataset[4]) # 显示第5张图片
# Out:
# Label :  Covid19

# %%
# 第3种方法：显示一张图片
def show_image(img):
    plt.figure(figsize=(8,8)) # 显示大小
    plt.imshow(img) # 显示图片
    plt.axis('off') # 关闭坐标轴
    plt.show()
    
# 读取图片
one_img = Image.open(dataloaders['train'].dataset.root+'Covid19/covid19 (10).jpg')

# 调用函数
show_image(one_img)

# %%
# 记录错误分类的图片
def misclassified_images(pred, writer, target, images, output, epoch, count=10):
    misclassified = (pred != target.data) # 判断是否一致
    for index, image_tensor in enumerate(images[misclassified][:count]):
        img_name = 'Epoch:{}-->Predict:{}-->Actual:{}'.format(epoch, LABEL[pred[misclassified].tolist()[index]],
                                                              LABEL[target.data[misclassified].tolist()[index]])
        writer.add_image(img_name, image_tensor, epoch)

# %%
# 自定义池化层

class AdaptiveConcatPool2d(nn.Module):
    def __init__(self, size=None):
        super(AdaptiveConcatPool2d,self).__init__()
        size = size or (1, 1) # kernel大小
        # 自适应算法能够自动帮助我们计算核的大小和每次移动的步长。
        self.avgPooling = nn.AdaptiveAvgPool2d(size) # 自适应平均池化
        self.maxPooling = nn.AdaptiveMaxPool2d(size) # 最大池化
    def forward(self, x):
        # 拼接avg和max
        return torch.cat([self.maxPooling(x), self.avgPooling(x)], dim=1)

# %%
# 迁移学习：获取预训练模型，并替换池化层和全连接层
# def get_model():
#     # 获取欲训练模型 restnet50
#     model = models.resnet50(pretrained=True) 
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False 
#     # 替换最后2层：池化层和全连接层
#     # 池化层
#     model.avgpool = AdaptiveConcatPool2d()
#     # 全连接层
#     model.fc = nn.Sequential(
#         nn.Flatten(), # 拉平
#         nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
#         nn.Dropout(0.5), # 丢掉部分神经元
#         nn.Linear(4096, 512), # 全连接层
#         nn.ReLU(), # 激活函数
#         nn.BatchNorm1d(512), 
#         nn.Dropout(0.5),
#         nn.Linear(512, 2), # 2个输出
#         nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
#     )
#     return model
# def get_model():
#     # 使用VGG-16预训练模型
#     model = models.vgg16(pretrained=True)
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False
#     # 替换最后两层
#     model.avgpool = AdaptiveConcatPool2d()
#     model.classifier = nn.Sequential(
#         nn.Dropout(),
#         nn.Linear(2 * 512, 256),
#         nn.ReLU(inplace=True),
#         nn.Dropout(),
#         nn.Linear(256, 4),
#         nn.LogSoftmax(dim=1)
#     )
#     return model

def get_model():
    # 获取欲训练模型 restnet50
    model = models.resnet101(pretrained=True) 
    # 冻结模型参数
    for param in model.parameters():
        param.requires_grad = False 
    # 替换最后2层：池化层和全连接层
    # 池化层
    model.avgpool = AdaptiveConcatPool2d()
    # 全连接层
    model.fc = nn.Sequential(
        nn.Flatten(), # 拉平
        nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
        nn.Dropout(0.5), # 丢掉部分神经元
        nn.Linear(4096, 512), # 全连接层
        nn.ReLU(), # 激活函数
        nn.BatchNorm1d(512), 
        nn.Dropout(0.5),
        nn.Linear(512, 2), # 2个输出
        nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
    )
    return model

# %%
# 定义训练函数
def train_val(model, device, train_loader, val_loader, optimizer, criterion, epoch, writer):
    model.train()
    total_loss = 0.0
    val_loss = 0.0
    val_acc = 0
    for batch_id, (images, labels) in enumerate(train_loader):
        # 部署到device上
        images, labels = images.to(device), labels.to(device)
        # 梯度置0
        optimizer.zero_grad()
        # 模型输出
        outputs = model(images)
        # 计算损失
        loss = criterion(outputs, labels)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 累计损失
        total_loss += loss.item() * images.size(0)
    # 平均训练损失
    train_loss = total_loss / len(train_loader.dataset)
    #写入到writer中
    writer.add_scalar('Training Loss', train_loss, epoch)
    # 写入到磁盘
    writer.flush()
    
    model.eval() 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images) # 前向传播输出
            loss = criterion(outputs, labels) # 损失
            val_loss += loss.item() * images.size(0) # 累计损失
            _, pred = torch.max(outputs, dim=1) # 获取最大概率的索引
            correct = pred.eq(labels.view_as(pred)) # 返回：tensor([ True,False,True,...,False])
            accuracy = torch.mean(correct.type(torch.FloatTensor)) # 准确率
            val_acc += accuracy.item() * images.size(0) # 累计准确率
        # 平均验证损失
        val_loss = val_loss / len(val_loader.dataset)
        # 平均准确率
        val_acc = val_acc / len(val_loader.dataset)
        
    return train_loss, val_loss, val_acc

# %%
# 定义测试函数
def test(model, device, test_loader, criterion, epoch, writer):
    model.eval()
    total_loss = 0.0
    correct = 0.0 # 正确数
    with torch.no_grad():
        for batch_id, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            # 输出
            outputs = model(images)
            # 损失
            loss = criterion(outputs, labels)
            # 累计损失
            total_loss += loss.item()
            # 获取预测概率最大值的索引
            _, predicted = torch.max(outputs, dim=1)
            # 累计正确预测的数
            correct += predicted.eq(labels.view_as(predicted)).sum().item()
            # 错误分类的图片
            misclassified_images(predicted, writer, labels, images, outputs, epoch)
        # 平均损失
        avg_loss = total_loss / len(test_loader.dataset)
        # 计算正确率
        accuracy = 100 * correct / len(test_loader.dataset)
        # 将test的结果写入write
        writer.add_scalar("Test Loss", total_loss, epoch)
        writer.add_scalar("Accuracy", accuracy, epoch)
        writer.flush()
        return total_loss, accuracy

# %%
# 定义训练流程

# 是否有GPU
#device = torch.device('cuda:6' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
print(device.type)

# 模型部署到device
model = get_model().to(device)

# 损失函数
criterion = nn.NLLLoss()

# 优化器
optimizer = optim.SGD(model.parameters(), lr=0.001)

# 定义训练流程函数
def train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer):
    # 输出信息
    print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format('Epoch', 'Train Loss', 'val_loss', 'val_acc', 'Test Loss', 'Test_acc'))
    # 初始最小的损失
    best_loss = np.inf
    # 开始训练、测试
    for epoch in range(epochs):
        # 训练，return: loss
        train_loss, val_loss, val_acc = train_val(model, device, dataloaders['train'], dataloaders['val'], optimizer, criterion, epoch, writer)
        # 测试，return: loss + accuracy
        test_loss, test_acc = test(model, device, dataloaders['test'], criterion, epoch, writer)
        # 判断损失是否最小
        if test_loss < best_loss:
            best_loss = test_loss # 保存最小损失
            # 保存模型
            torch.save(model.state_dict(), 'model1.pth')
        # 输出结果
        print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format(epoch, train_loss, val_loss, val_acc, test_loss, test_acc))
        writer.flush()
# Out:
# cpu
# E:\ProgramData\Anaconda3\envs\my_en3.7\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# E:\ProgramData\Anaconda3\envs\my_en3.7\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 调用函数
epochs=40
train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
writer.close()
# Out:
#           Epoch |      Train Loss |        val_loss |         val_acc |       Test Loss |        Test_acc
#               0 | 0.470824100625515 | 0.34634607911109927 | 0.8671428564616612 | 4.300735741853714 |            85.5
#               1 | 0.2619142191410065 | 0.20314123562404088 | 0.927142858845847 | 2.4817570745944977 | 92.21428571428571
#               2 | 0.2042161497116089 | 0.16992581060954504 | 0.9385714261872428 | 2.2041086852550507 | 92.64285714285714
#               3 | 0.1877656126022339 | 0.1416653114557266 | 0.9485714275496346 | 2.057533472776413 | 93.35714285714286
#               4 | 0.1693675976753235 | 0.164282665678433 | 0.9242857132639204 | 2.1302771642804146 | 91.78571428571429
#               5 | 0.15678083411455154 | 0.14771000146865845 | 0.9400000003405979 | 2.0261915624141693 | 92.57142857142857
#               6 | 0.14989789187908173 | 0.1277423853959356 | 0.9428571404729571 | 1.942154809832573 | 93.35714285714286
#               7 | 0.14136837964057922 | 0.12874095448425837 | 0.9414285731315613 | 1.9384347721934319 | 93.07142857142857
#               8 | 0.13176024858951568 | 0.1347798131619181 | 0.9342857132639204 | 1.9650654941797256 | 92.85714285714286
#               9 | 0.13068182328343392 | 0.12622945410864694 | 0.9399999989782061 | 1.9203964173793793 | 93.07142857142857
#              10 | 0.13789026947021485 | 0.1299796142748424 | 0.9414285704067775 | 1.942404605448246 | 92.71428571428571
#              11 | 0.11866608020067215 | 0.11840297937393189 | 0.9657142860548836 | 2.0732652693986893 | 93.21428571428571
#              12 | 0.1251870215564966 | 0.13427683327879225 | 0.9371428574834552 | 1.9307261779904366 | 92.42857142857143
#              13 | 0.1220990177154541 | 0.12309162135635103 | 0.9414285690443857 | 1.9067893624305725 | 92.71428571428571
#              14 | 0.11966898076534271 | 0.1311202634232385 | 0.9342857146263123 | 1.9288090616464615 |            92.5
#              15 | 0.11749941439628601 | 0.14819237411022188 | 0.9257142860548837 | 1.9967752546072006 | 92.42857142857143
#              16 | 0.11216917107105255 | 0.13662882770810808 | 0.9314285717691694 | 1.9460493624210358 |            92.5
#              17 | 0.11474887471199036 | 0.12090789658682687 | 0.9400000017029898 | 1.920999825000763 | 92.71428571428571
#              18 | 0.11207977699041366 | 0.12117552621023996 | 0.9414285704067775 | 1.8698449581861496 | 92.78571428571429
#              19 | 0.11197814197540283 | 0.15181955056531088 | 0.9228571404729571 | 2.02042593061924 | 92.14285714285714
#              20 | 0.11677090740203858 | 0.11688762673309872 | 0.950000000340598 | 1.856751099228859 | 92.85714285714286
#              21 | 0.10956336573213339 | 0.13995322746889932 | 0.9257142860548837 | 1.9552087038755417 | 92.42857142857143
#              22 | 0.1142851970255375 | 0.14048811401639666 | 0.9300000003405979 | 1.9703301042318344 | 92.21428571428571
#              23 | 0.11469145232439042 | 0.1235998626266207 | 0.9385714261872428 | 1.907196894288063 | 92.92857142857143
#              24 | 0.09758860840797424 | 0.126561302287238 | 0.9400000003405979 | 1.889245219528675 | 92.92857142857143
#              25 | 0.10743219985961915 | 0.12894497283867426 | 0.9300000017029898 | 1.8880501836538315 | 92.57142857142857
#              26 | 0.10649787602424622 | 0.1299653263602938 | 0.9357142874172756 | 1.8883583173155785 | 92.92857142857143
#              27 | 0.09756973540484905 | 0.1157602506024497 | 0.9400000003405979 | 1.849589817225933 | 93.07142857142857
#              28 | 0.10330123701095581 | 0.12306252253907067 | 0.9442857132639204 | 1.8188441544771194 | 93.07142857142857
#              29 | 0.10310036489367486 | 0.12891465621335166 | 0.9371428550992693 | 1.8775456547737122 | 92.85714285714286
#              30 | 0.1067771337196231 | 0.11740591074739183 | 0.9457142860548837 | 1.866374060511589 | 92.78571428571429
#              31 | 0.10000184247493744 | 0.11320645689964294 | 0.9428571445601327 | 1.8510184586048126 | 93.78571428571429
#              32 | 0.09877911400794982 | 0.10640199869871139 | 0.9542857146263123 | 1.8349447175860405 | 93.28571428571429
#              33 | 0.09650906915664673 | 0.09811116193022047 | 0.9614285727909633 | 1.8099549189209938 | 93.28571428571429
#              34 | 0.10373202943578362 | 0.12386958181858063 | 0.9342857142857143 | 1.8436818569898605 |            93.0
#              35 | 0.09795410749912262 | 0.13003003656864165 | 0.9357142870766776 | 1.8873423263430595 | 92.92857142857143
#              36 | 0.10319225749969482 | 0.11053990645068032 | 0.9514285704067775 | 1.8146744966506958 | 93.35714285714286
#              37 | 0.10369186086654664 | 0.15792822650500707 | 0.9185714265278407 | 1.9659915268421173 | 92.28571428571429
#              38 | 0.09700297765731812 | 0.138050129030432 | 0.9285714275496346 | 1.8963684365153313 | 92.85714285714286
#              39 | 0.0947622868180275 | 0.11884205792631422 | 0.9414285690443857 |  1.828493706882 | 93.14285714285714

# %%
# import cv2


# # 定义 Grad-CAM 类
# class GradCAM:
#     def __init__(self, model, target_layer):
#         self.model = model
#         self.target_layer = target_layer
#         self.feature_maps = None
#         self.gradient = None

#     def save_gradient(self, gradient):
#         self.gradient = gradient
        
#     def __call__(self, input):
#         # 调整维度
#         input = input.squeeze(0)
#         input = torch.transpose(input, 0, 1)

#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             input = module(input)
#             if name == self.target_layer:
#                 input.register_hook(self.save_gradient)
#                 self.feature_maps = input.detach()
#         output = input

#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, input.shape[1:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)

#         return cam


#     def __call__(self, x):
#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             x = module(x)
#             if name == self.target_layer:
#                 x.register_hook(self.save_gradient)
#                 self.feature_maps = x.detach()
#         output = x
#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, x.shape[2:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)
#         return cam

# 获取模型
# model = get_model()
# # 加载预训练权重
# model.load_state_dict(torch.load('model2.pth', map_location=torch.device('cpu')))
# # 设置为评估模式
# model.eval()
# # 定义 Grad-CAM 对象
# grad_cam = GradCAM(model, 'layer4') # 这里选择 ResNet50 的 layer4 层作为目标层

# # 加载目标图像并预处理
# image = cv2.imread('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image = cv2.resize(image, (224, 224))
# image = image / 255.
# image = (image - [0.485, 0.456, 0.406]) / [0.229, 0.224, 0.225]
# image = np.transpose(image, (2, 0, 1))
# image = np.expand_dims(image, axis=0)
# image = torch.from_numpy(image).float()

# # 使用 Grad-CAM 进行可视化
# with torch.set_grad_enabled(True):
#     output = model(image)
#     _, pred = output.max(dim=1)
#     cam = grad_cam(image)
#     cam = cv2.resize(cam, (224, 224))
#     heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
#     heatmap = np.float32(heatmap) / 255
#     cam_on_image = heatmap + np.float32(cv2.cvtColor(np.uint8(255*image[0].permute(1,2,0).cpu().numpy()), cv2.COLOR_BGR2RGB))
#     cam_on_image = cam_on_image / np.max(cam_on_image)

# # 显示结果
# import matplotlib.pyplot as plt
# plt.imshow(cam_on_image)
# plt.axis('off')
# plt.show()

# %%
# import cv2
# import numpy as np
# import torch
# from torchvision import models, transforms
# from torch.nn import functional as F
# from matplotlib import pyplot as plt

# # 定义Grad-CAM可视化函数
# class GradCam:
#     def __init__(self, model, target_layer_names):
#         self.model = model
#         self.target_layer_names = target_layer_names
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.model.eval()
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#     def register_hook(self, module):
#         def hook(module, input, output):
#             self.feature_maps.append(output.cpu().data.numpy())

#         return module.register_forward_hook(hook)

#     def remove_handlers(self):
#         for handle in self.handlers:
#             handle.remove()

#     def __call__(self, x):
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#         outputs = self.model(x)
#         one_hot = outputs.detach().zero_()
#         one_hot[0][torch.argmax(outputs)] = 1
#         one_hot.requires_grad = True
#         one_hot = torch.sum(one_hot * outputs)

#         self.model.zero_grad()
#         one_hot.backward(retain_graph=True)

#         self.gradient_maps = []
#         for i, name in enumerate(self.target_layer_names):
#             gradient_map = (
#                 self.feature_maps[i][0] * self.gradient_maps[-1]
#                 if len(self.gradient_maps) > 0
#                 else self.feature_maps[i][0]
#             )
#             self.gradient_maps.append(gradient_map)

#         self.remove_handlers()
#         return self.gradient_maps[-1]

# # 定义输入图像预处理函数
# def preprocess_image(img_path):
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, (224, 224))
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img_tensor = transforms.ToTensor()(img)
#     img_tensor = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(img_tensor)
#     img_tensor = img_tensor.unsqueeze(0)
#     return img_tensor

# # 加载模型
# model = get_model()
# # 加载图像
# img_tensor = preprocess_image('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# # 运行Grad-CAM可视化
# torch.autograd.set_detect_anomaly(True)
# cam = GradCam(model, ['layer4'])
# grad_cam = cam(img_tensor)
# # 将可视化结果转换为热力图
# grad_cam = np.mean(grad_cam, axis=(1, 2), keepdims=True)
# grad_cam = np.maximum(grad_cam, 0)
# grad_cam = grad_cam / grad_cam.max()
# # 将热力图叠加到原始图像上
# img = cv2.imread(dataloaders['train'].dataset.root+'BacterialPneumonia/101.jpeg')
# grad_cam = cv2.resize(grad_cam[0], (img.shape[1], img.shape[0]))
# grad_cam = cv2.applyColorMap(np.uint8(255 * grad_cam), cv2.COLORMAP_JET)
# output_image = cv2.addWeighted(img, 0.8, grad_cam, 0.4, 0)
# # 显示结果
# plt.imshow(output_image[...,::-1])
# plt.axis('off')
# plt

# %%
def plot_confusion(cm):
    plt.figure()
    plot_confusion_matrix(cm, figsize=(12, 8), cmap=plt.cm.Blues) # 参数设置
    plt.xticks(range(2), ['Covid19', 'Normal'], fontsize=14)
    plt.yticks(range(2), ['Covid19', 'Normal'], fontsize=14)
    plt.xlabel('Predicted Label', fontsize=16)
    plt.ylabel('True Label', fontsize=16)
    plt.show()

# %%
# def accuracy(outputs, labels):
#     # 计算正确率
#     _, preds = torch.max(outputs, dim=1)
#     correct = torch.tensor(torch.sum(preds == labels).item() / len(preds))
#     return correct

# %%
# def metrics(outputs, labels):
#     _, preds = torch.max(outputs, dim=1)
#     # precision, recall, F1
#     # 混淆矩阵
#     cm = confusion_matrix(labels.cpu().numpy(), preds.cpu().numpy())
#     # 绘制混淆矩阵
#     plot_confusion(cm) 
#     # 获取tn, fp, fn, tp
# #     tn, fp, fn, tp = cm.ravel()
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
#     print(tn)
#     print(fp)
#     # 精准率
#     precision = tp / (tp + fp)
#     # 召回率
#     recall = tp / (tp + fn)
#     # f1 score
#     f1 = 2 * ((precision * recall) / (precision + recall))
#     return precision, recall, f1

# %%
all_preds = []
all_labels = []

with torch.no_grad():
    model.eval()
    for datas, labels in dataloaders['test']:
        datas, labels = datas.to(device), labels.to(device)
        # 预测输出 前向传播
        outputs = model(datas)
        _, preds = torch.max(outputs, dim=1)
#     将预测结果和真实标签添加到列表中
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        # precision, recall, F1
        # 混淆矩阵
    cm = confusion_matrix(all_labels, all_preds)
    # 绘制混淆矩阵
    plot_confusion(cm) 
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
    tn, fp, fn, tp = cm.ravel()
    # 精准率
    precision = tp / (tp + fp)
    # 召回率
    recall = tp / (tp + fn)
    # f1 score
    f1 = 2 * ((precision * recall) / (precision + recall))
    num_correct = 0
    num_total = len(all_labels)
    for pred, label in zip(all_preds, all_labels):
        if pred == label:
            num_correct += 1
            acc = num_correct / num_total
#     acc = torch.tensor(torch.sum(all_preds == all_labels.data).item() / len(all_preds))
    print(precision)
    print(recall)
    print(f1)
    print(acc)

# with torch.no_grad():
#     model.eval()
#     for datas, labels in dataloaders['val']:
#         datas, labels = datas.to(device), labels.to(device)
#         # 预测输出
#         outputs = model(datas)
#         # 计算metrics
#         precision, recall, f1 = metrics(outputs, labels)
#         acc = accuracy(outputs, labels)
#         # 保存结果
#         precisions.append(precision)
#         recalls.append(recall)
#         f1s.append(f1)
#         accuracies.append(acc.item())
#         print(precisions)
#         print(recalls)
# Out:
# 0.9289772727272727
# 0.9342857142857143
# 0.9316239316239315
# 0.9314285714285714

# %%
# ['{:.2f}%'.format(pre*100) for pre in precisions]# 精准率 precision

# %%
# ['{:.2f}%'.format(r*100) for r in recalls]# 召回率 recall

# %%
# ['{:.2f}%'.format(f*100) for f in f1s]# f1

# %%
# ['{:.2f}%'.format(a*100) for a in accuracies]# 准确率 accuracy
